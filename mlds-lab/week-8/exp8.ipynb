# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-0b6fcc9f-cd0a-4a8f-b5c2-5d733550a4b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b6fcc9f-cd0a-4a8f-b5c2-5d733550a4b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
train=pd.read_csv("train.csv")
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
test=pd.read_csv("test.csv")
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
print(train.columns)
print(test.columns)
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
print(train.shape, test.shape)
# Out:
# (614, 13) (367, 12)

# %%
train['Loan_Status'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
train['Gender'].value_counts(normalize=True).plot.bar(title='Gender')
# Out:
# <Axes: title={'center': 'Gender'}, xlabel='Gender'>

# %%
train['Married'].value_counts(normalize=True).plot.bar(title='Married')
# Out:
# <Axes: title={'center': 'Married'}, xlabel='Married'>

# %%
train['Self_Employed'].value_counts(normalize=True).plot.bar(title='Self_employee')
# Out:
# <Axes: title={'center': 'Self_employee'}, xlabel='Self_Employed'>

# %%
train['Credit_History'].value_counts(normalize=True).plot.bar(title='Credit_History')
# Out:
# <Axes: title={'center': 'Credit_History'}, xlabel='Credit_History'>

# %%
train['Dependents'].value_counts(normalize=True).plot.bar(title='Dependents')
# Out:
# <Axes: title={'center': 'Dependents'}, xlabel='Dependents'>

# %%
train['Education'].value_counts(normalize=True).plot.bar(title='Education')
# Out:
# <Axes: title={'center': 'Education'}, xlabel='Education'>

# %%
train['Property_Area'].value_counts(normalize=True).plot.bar(title='Property_Area')
# Out:
# <Axes: title={'center': 'Property_Area'}, xlabel='Property_Area'>

# %%
train['ApplicantIncome'].value_counts(normalize=True).plot.bar(title='ApplicantIncome')
# Out:
# <Axes: title={'center': 'ApplicantIncome'}, xlabel='ApplicantIncome'>

# %%
train['CoapplicantIncome'].plot.box()
# Out:
# <Axes: >

# %%
train['LoanAmount'].plot.box()
# Out:
# <Axes: >

# %%
Gender=pd.crosstab(train['Gender'],train['Loan_Status'])

print(Gender)
# Out:
# Loan_Status    N    Y
# Gender
# Female        37   75
# Male         150  339

# %% [markdown]
# prcessing to represent categorical as binary vectors

# %%
Gender=pd.crosstab(train['Gender'],train['Loan_Status'])
Gender.div(Gender.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
# Out:
# <Axes: xlabel='Gender'>

# %%
#train.replace({'Married	':{'Yes':1 ,'NO':0}, 'Gender':{"Male": 1, "Female" : 0}, 'Education':{'Graduate':1, 'Not Graduate':0 }, 'Self_Employed':{'Yes':1, 'No':0}, 'Property_Area':{'Urban':1, 'Rural':2, 'Semiurban':3}, 'Dependents':{'3+':3}}, inplace=True)

# %%
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# train['Gender'] = le.fit_transform(train['Gender'])

df_heatmap = train.select_dtypes(include =[ 'int', 'float'])
plt.figure(figsize=(12,8))
sns.heatmap(df_heatmap.corr() ,vmax=.8,square=True,cmap="BuPu",annot=True)
plt.show()

# %%
train.head()
# Out:
#    Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0     1.0      0.0          1            0.0             5849
# 1     1.0      1.0          1            0.0             4583
# 2     1.0      1.0          1            1.0             3000
# 3     1.0      1.0          0            0.0             2583
# 4     1.0      0.0          1            0.0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       120.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area  Loan_Status  Dependents_3  Dependents_0  Dependents_1  \
# 0              1            1         False          True         False
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(matrix,vmax=.8,square=True,cmap="BuPu",annot=True)
plt.show()

# %%
train.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           13
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train['Gender'].fillna(train['Gender'].mode()[0],inplace=True)
print(train['Gender'])
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 609    0.0
# 610    1.0
# 611    1.0
# 612    1.0
# 613    0.0
# Name: Gender, Length: 614, dtype: float64

# %%
train['Married'].fillna(train['Married'].mode()[0],inplace=True)
print(train['Married'])
# Out:
# 0      0.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      0.0
#       ...
# 609    0.0
# 610    1.0
# 611    1.0
# 612    1.0
# 613    0.0
# Name: Married, Length: 614, dtype: float64

# %%
train['Dependents'].fillna(train['Dependents'].mode()[0],inplace=True)
print(train['Dependents'])
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 609    0
# 610    3
# 611    1
# 612    2
# 613    0
# Name: Dependents, Length: 614, dtype: object

# %%
train['Self_Employed'].fillna(train['Self_Employed'].mode()[0],inplace=True)
print(train['Self_Employed'])
# Out:
# 0      0.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      0.0
#       ...
# 609    0.0
# 610    0.0
# 611    0.0
# 612    0.0
# 613    1.0
# Name: Self_Employed, Length: 614, dtype: float64

# %%
train['LoanAmount'].fillna(train['LoanAmount'].mode()[0],inplace=True)
print(train['LoanAmount'])
# Out:
# 0      120.0
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %%
train['Loan_Amount_Term'].fillna(train['Loan_Amount_Term'].mean(),inplace=True)
print(train['LoanAmount'])
# Out:
# 0      120.0
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %%
train['Credit_History'].fillna(train['Credit_History'].mean(),inplace=True)
print(train['Credit_History'])
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 609    1.0
# 610    1.0
# 611    1.0
# 612    1.0
# 613    0.0
# Name: Credit_History, Length: 614, dtype: float64

# %%
train.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
X = train.drop('Loan_Status',axis=1)
Y = train.Loan_Status
train = train.copy()
test = test.copy()
X = pd.get_dummies(X)
plt.ylabel = pd.get_dummies(X)
train=pd.get_dummies(train)
test=pd.get_dummies(test)
print(X)
print(Y)
# Out:
#      Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0       1.0      0.0          1            0.0             5849
# 1       1.0      1.0          1            0.0             4583
# 2       1.0      1.0          1            1.0             3000
# 3       1.0      1.0          0            0.0             2583
# 4       1.0      0.0          1            0.0             6000
# ..      ...      ...        ...            ...              ...
# 609     0.0      0.0          1            0.0             2900
# 610     1.0      1.0          1            0.0             4106
# 611     1.0      1.0          1            0.0             8072
# 612     1.0      1.0          1            0.0             7583
# 613     0.0      0.0          1            1.0             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0       120.0             360.0             1.0
# ...

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
clf=model.fit(X,Y)
df=pd.read_csv('test.csv')
print(df)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)
df['Dependents'].fillna(df['Dependents'].mode()[0],inplace=True)
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0],inplace=True)
df['LoanAmount'].fillna(df['LoanAmount'].mean(),inplace=True)
#df['Loan_Amount_Term'].fillna(df[Loan_Amount_Term].mean(),inplace=True)
df['Credit_History'].fillna(df['Credit_History'].mean(),inplace=True)

# %%
df.isnull().sum()
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
df=df.drop('Loan_ID',axis=1)
df=pd.get_dummies(df)
print(X)
print(df)
# Out:
#      Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0       1.0      0.0          1            0.0             5849
# 1       1.0      1.0          1            0.0             4583
# 2       1.0      1.0          1            1.0             3000
# 3       1.0      1.0          0            0.0             2583
# 4       1.0      0.0          1            0.0             6000
# ..      ...      ...        ...            ...              ...
# 609     0.0      0.0          1            0.0             2900
# 610     1.0      1.0          1            0.0             4106
# 611     1.0      1.0          1            0.0             8072
# 612     1.0      1.0          1            0.0             7583
# 613     0.0      0.0          1            1.0             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0       120.0             360.0             1.0
# ...

# %%
clf.predict(df)
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N',
# ...
